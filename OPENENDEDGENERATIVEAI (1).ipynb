# %%
# !pip install -q streamlit
# !pip install -q transformers
# !pip install -q torch
# !pip install -q langchain
# !pip install -q langchain-community
# !pip install -q langchain-huggingface
# !pip install -q langchain-text-splitters
# !pip install -q sentence-transformers
# !pip install -q faiss-cpu
# !pip install -q accelerate
# !npm install -g localtunnel
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 35.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 42.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 32.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 64.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.1/548.1 kB 38.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 78.1 MB/s eta 0:00:00
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧
# added 22 packages in 2s
# ⠧
# ...

# %%
data = """
[COLLEGE NAME]
The college name is BMS Institute of Technology and Management (BMSIT&M), Bengaluru. The institution is known for engineering, management, and technology education with modern infrastructure and academic excellence.

[ABOUT COLLEGE]
BMS Institute of Technology and Management is affiliated with Visvesvaraya Technological University (VTU) and approved by AICTE. The college focuses on academics, placements, research, innovation, and extracurricular activities.

[ADMISSION PROCESS]
Students can apply online through the official college admission portal. Admissions are offered based on entrance exams such as KCET, COMEDK, and management quota procedures. Students must submit academic documents, photographs, ID proof, and entrance exam details during admission.

[ELIGIBILITY]
Students applying for B.Tech programs must complete 12th grade with Physics, Chemistry, and Mathematics (PCM). MBA and MCA applicants should possess a relevant undergraduate degree from a recognized university.

[COURSES OFFERED]
The college offers undergraduate, postgraduate, and doctoral programs including B.Tech, MBA, MCA, M.Tech, and PhD programs in various specializations.

[DEPARTMENTS]
Departments include Computer Science Engineering (CSE), Artificial Intelligence and Machine Learning (AIML), Information Science Engineering (ISE), Electronics and Communication Engineering (ECE), Electrical and Electronics Engineering (EEE), Mechanical Engineering, Civil Engineering, and MBA.

[PLACEMENTS]
The college has an excellent placement record with support from the training and placement department. Students receive placement training, aptitude preparation, mock interviews, coding practice, resume-building sessions, and soft-skill development programs.

[TOP RECRUITERS]
Top recruiters visiting the campus include Amazon, Infosys, TCS, Wipro, Accenture, Capgemini, Cognizant, IBM, Deloitte, Microsoft, and Bosch.

[HIGHEST PACKAGE]
The highest placement package offered to students reached 45 LPA during recent placement drives.

[AVERAGE PACKAGE]
The average placement package offered to students is around 6 LPA depending on the department and skill set.

[INTERNSHIPS]
Students receive internship opportunities from third year onwards. Many companies provide paid internships, industry projects, and training programs to help students gain practical experience.

[HOSTEL FACILITIES]
Separate hostel facilities are available for boys and girls with WiFi, security, laundry, study rooms, hot water, and recreational areas.

[HOSTEL FEES]
Hostel fees range from INR 80,000 to INR 1,20,000 per year depending on room type and facilities.

[LIBRARY]
The central library is open from 8 AM to 8 PM on working days. Students can access textbooks, reference books, journals, research papers, magazines, and academic materials.

[DIGITAL LIBRARY]
Students can access online journals, e-books, IEEE papers, NPTEL resources, and digital learning platforms through the digital library.

[ATTENDANCE RULE]
Students must maintain at least 75% attendance in every semester as per academic regulations.

[SCHOLARSHIPS]
Merit-based scholarships, government scholarships, SC/ST scholarships, minority scholarships, and financial assistance programs are available for eligible students.

[SPORTS]
The campus provides facilities for cricket, football, basketball, volleyball, badminton, table tennis, athletics, and gym activities. Students participate in inter-college sports competitions regularly.

[CAFETERIA]
The college cafeteria serves hygienic vegetarian and non-vegetarian food with snacks, beverages, meals, and refreshments at affordable prices.

[TRANSPORT]
College buses are available across different areas of Bengaluru for students and faculty members.

[WIFI]
High-speed WiFi connectivity is available throughout the campus including classrooms, labs, hostels, and library areas.

[LABORATORIES]
Modern computer labs, electronics labs, mechanical workshops, and research laboratories are available with updated equipment and software tools.

[EXAM PATTERN]
Semester examinations are conducted twice every academic year along with internal assessments, assignments, and laboratory evaluations.

[GRADING SYSTEM]
The college follows the CGPA grading system under VTU academic regulations.

[CLUBS]
Students can participate in coding clubs, robotics clubs, dance clubs, music clubs, photography clubs, entrepreneurship cells, and literary clubs.

[HACKATHONS]
The college regularly conducts hackathons, coding contests, innovation challenges, technical events, and project competitions.

[EVENTS]
Annual cultural festivals, technical fests, sports meets, freshers' events, farewell functions, and department-level activities are organized every year.

[FACULTY]
Experienced professors, researchers, and industry experts guide students in academics, projects, and research activities.

[RESEARCH]
Research opportunities are available for final-year students and postgraduate students in areas like AI, Machine Learning, Data Science, IoT, Robotics, and Cloud Computing.

[NSS]
Students can participate in National Service Scheme (NSS) activities including social service, awareness campaigns, blood donation camps, and rural development programs.

[NCC]
NCC training is available for interested students to develop leadership, discipline, and defense-related skills.

[MEDICAL FACILITY]
Basic medical facilities, first aid support, emergency care, and health checkup facilities are available on campus.

[BANK FACILITY]
ATM and banking services are available inside the campus for students and staff members.

[PARKING]
Large parking facilities are available for bicycles, bikes, and cars inside the campus.

[ANTI-RAGGING]
The college follows strict anti-ragging policies and maintains a safe and secure environment for students.

[STUDENT SUPPORT]
Counseling, mentoring, placement guidance, career support, and academic assistance are provided for students.

[ONLINE LEARNING]
Students can access online learning platforms, recorded lectures, virtual labs, and digital course materials.

[CAMPUS SIZE]
The campus is spread across several acres with modern buildings, laboratories, classrooms, seminar halls, playgrounds, and green surroundings.

[CLASS TIMINGS]
Classes generally begin at 9 AM and end at 4 PM on working days.

[DRESS CODE]
Students are expected to wear decent and formal attire during academic hours and laboratory sessions.

[ID CARD]
Students must carry college ID cards inside the campus at all times.

[INDUSTRIAL VISITS]
Departments organize industrial visits and company tours regularly to provide practical exposure.

[WORKSHOPS]
Technical workshops, coding bootcamps, guest lectures, seminars, and certification training programs are conducted frequently.

[CERTIFICATIONS]
Students can enroll in certification programs related to AWS, Artificial Intelligence, Machine Learning, Cybersecurity, Cloud Computing, and Data Science.

[ALUMNI NETWORK]
The college has a strong alumni network working in reputed companies across India and abroad.

[ENTREPRENEURSHIP]
Startup incubation support, entrepreneurship programs, innovation labs, and funding guidance are provided for aspiring entrepreneurs.

[CAMPUS SECURITY]
24/7 security personnel, CCTV surveillance, and secure campus monitoring systems are available for student safety.

[HOLIDAY LIST]
Academic holidays and semester schedules are announced through the official college portal and notice boards.

[RESULTS]
Semester examination results are published online through the university and college portals.

[REVALUATION]
Students can apply for answer script photocopy and revaluation after examination results are announced.

[CONTACT]
Students can contact the administration through official email, helpline numbers, department offices, and the college website.
"""

with open("college_faq.txt", "w") as f:
    f.write(data)

print("Dataset Created!")
# Out:
# Dataset Created!

# %%
# %%writefile app.py

import streamlit as st

from transformers import pipeline

from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import TextLoader
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS

# ------------------------------------------------
# PAGE CONFIG
# ------------------------------------------------

st.set_page_config(
    page_title="College FAQ Chatbot",
    page_icon="🎓",
    layout="wide"
)

# ------------------------------------------------
# CUSTOM CSS
# ------------------------------------------------

st.markdown("""
<style>

.stApp {
    background-color: #0f172a;
    color: white;
}

h1, h2, h3 {
    color: #38bdf8;
}

.user-msg {
    background-color: #1e293b;
    padding: 12px;
    border-radius: 10px;
    margin-bottom: 10px;
}

.bot-msg {
    background-color: #334155;
    padding: 12px;
    border-radius: 10px;
    margin-bottom: 10px;
}

</style>
""", unsafe_allow_html=True)

# ------------------------------------------------
# TITLE
# ------------------------------------------------

st.title("🎓 College FAQ RAG Chatbot")

st.write("Ask questions related to college facilities, placements, attendance, hostel, etc.")

# ------------------------------------------------
# SIDEBAR
# ------------------------------------------------

st.sidebar.header("⚙️ Settings")

top_k = st.sidebar.slider(
    "Top-K Documents",
    1,
    5,
    2
)

temperature = st.sidebar.slider(
    "Temperature",
    0.1,
    1.0,
    0.7
)

# ------------------------------------------------
# LOAD VECTORSTORE
# ------------------------------------------------

@st.cache_resource
def load_vectorstore():

    loader = TextLoader("college_faq.txt")

    documents = loader.load()

    splitter = RecursiveCharacterTextSplitter(
        chunk_size=300,
        chunk_overlap=50
    )

    docs = splitter.split_documents(documents)

    embedding_model = HuggingFaceEmbeddings(
        model_name="sentence-transformers/all-MiniLM-L6-v2"
    )

    vectorstore = FAISS.from_documents(
        docs,
        embedding_model
    )

    return vectorstore

vectorstore = load_vectorstore()

# ------------------------------------------------
# LOAD MODEL
# ------------------------------------------------

@st.cache_resource
def load_model():

    generator = pipeline(
        "text-generation",
        model="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
        max_new_tokens=200
    )

    return generator

generator = load_model()

# ------------------------------------------------
# SESSION STATE
# ------------------------------------------------

if "chat_history" not in st.session_state:
    st.session_state.chat_history = []

# ------------------------------------------------
# USER INPUT
# ------------------------------------------------

query = st.text_input("Enter your question:")

send = st.button("Send")

# ------------------------------------------------
# PROCESS QUERY
# ------------------------------------------------

if send and query:

    docs = vectorstore.similarity_search(
        query,
        k=top_k
    )

    context = "\n".join(
        [doc.page_content for doc in docs]
    )

    prompt = f"""
    You are a helpful college assistant.

    Context:
    {context}

    Question:
    {query}

    Answer:
    """

    response = generator(
        prompt,
        max_new_tokens=200,
        temperature=temperature
    )

    answer = response[0]["generated_text"]

    st.session_state.chat_history.append(
        ("You", query)
    )

    st.session_state.chat_history.append(
        ("Bot", answer)
    )

# ------------------------------------------------
# DISPLAY CHAT HISTORY
# ------------------------------------------------

for sender, message in st.session_state.chat_history:

    if sender == "You":

        st.markdown(
            f"""
            <div class="user-msg">
            <b>🧑 You:</b><br>
            {message}
            </div>
            """,
            unsafe_allow_html=True
        )

    else:

        st.markdown(
            f"""
            <div class="bot-msg">
            <b>🤖 Bot:</b><br>
            {message}
            </div>
            """,
            unsafe_allow_html=True
        )
# Out:
# Writing app.py

# %%
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb
# Out:
# Selecting previously unselected package cloudflared.
# (Reading database ... 118252 files and directories currently installed.)
# Preparing to unpack cloudflared-linux-amd64.deb ...
# Unpacking cloudflared (2026.5.0) ...
# Setting up cloudflared (2026.5.0) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !streamlit run app.py >/content/logs.txt 2>&1 &

# %%
# !cloudflared tunnel --url http://localhost:8501
# Out:
# 2026-05-15T05:03:43Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2026-05-15T05:03:43Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2026-05-15T05:03:46Z INF +--------------------------------------------------------------------------------------------+
# 2026-05-15T05:03:46Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# ...
